# %%
# Importer les bibliothèques nécessaires
from lingua import Language, LanguageDetectorBuilder
from transformers import pipeline
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm
import pandas as pd
import re

# %%
# Initialisation du détecteur de langue
detector = LanguageDetectorBuilder.from_languages(
    Language.FRENCH, 
    Language.ENGLISH
).with_preloaded_language_models().build()

# %%
def detect_language_lingua(text):
    result = detector.detect_language_of(text)
    return "fr" if result == Language.FRENCH else "en" if result == Language.ENGLISH else "unknown"

# %%
# Charger un modèle de traduction léger (Helsinki-NLP)
translator = pipeline(
    "translation_en_to_fr", 
    model="Helsinki-NLP/opus-mt-en-fr",
    device=-1  # CPU
)
# Out:
# c:\Users\my.kassem\Desktop\Intelligent_analysis_of_JIRA_tickets\.venv\lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Device set to use cpu

# %%
# Fonction pour nettoyer le texte
def clean_text(text):
    if not isinstance(text, str):
        return ""
    text = text.replace("\r", "").replace("\n", " ")  # Supprime les retours à la ligne
    text = re.sub(r'\s+', ' ', text).strip()  # Supprime les espaces multiples
    return text

# %%
# Fonction de traduction
def translate_corpus(texts, workers=4):
    def process_text(text):
        lang = detect_language_lingua(text)
        if lang == 'en':
            try:
                return translator(text, max_length=512)[0]['translation_text']
            except:
                return text  # En cas d'erreur, conserve l'original
        return text
    
    with ThreadPoolExecutor(max_workers=workers) as executor:
        return list(tqdm(executor.map(process_text, texts), total=len(texts)))

# %%
# Charger le fichier CSV
df = pd.read_csv('C:/Users/my.kassem/Desktop/exploratory data analysis/df_filtre_status_type_description_resolution_copy.csv')

# %%
df
# Out:
#                Key         Type  \
# 0      DHRD-103268     Incident
# 1      DHRD-103216        Story
# 2      DHRD-103195      Problem
# 3      DHRD-103180          Bug
# 4      DHRD-103113          Bug
# ...            ...          ...
# 15976    DHRD-7282          Bug
# 15977    DHRD-7281  Improvement
# 15978    DHRD-7280          Bug
# 15979    DHRD-7279      Request
# 15980    DHRD-6497          Bug
#
#                                                  Summary  \
# 0      CACEIS-PROD-IN-CP - Licence expirée depuis le ...
# 1         TST - Manual override / Audit must be retested
# 2                                    Can't Start Workers
# 3        [AWS] S3 services failure with AWS_ROLE channel
# 4      [Regression] : NPE raised when using the Share...
# ...                                                  ...
# 15976                    Import error : deadlock failure
# 15977  Evolutions mineures sur l'environnement des bu...
# 15978     L'icone des mails interne en attente est HS...
# 15979                                            Ratings
# 15980  Probleme lors de l'affichage de l'agregation d...
#
#                                              Description    Status Resolution  \
# 0      Bonjour à tous,\r\nNous avons CACEIS qui nous ...  Resolved      Fixed
# 1      Due to improvements done with  DHRD-100447, th...      Done      Fixed
# 2      ||Version details||Environment infos||\r\n| * ...  Resolved      Fixed
# 3      ||Version details||Environment infos||\r\n| * ...      Done      Fixed
# 4      ||Version details||Environment infos||\r\n|VER...      Done      Fixed
# ...                                                  ...       ...        ...
# 15976  When importing a file, the error "* Main error...    Closed      Fixed
# 15977  Bizness rule:\no chercher une autre bizule en ...    Closed      Fixed
# 15978  L'icone de boîte mail situé en bas de l'écran ...    Closed      Fixed
# 15979  Titres : \n - Les ratings côté titre sont faux...    Closed      Fixed
# 15980  XT - 26/05/2011 - Mail de Mickael et il fourni...    Closed     Closed
#
#                     Resolution Date  \
# 0      2025-01-23T10:45:39.000+0100
# 1      2025-01-24T10:36:04.000+0100
# 2      2025-01-22T16:24:24.000+0100
# 3      2025-01-22T14:36:37.000+0100
# 4      2025-01-23T09:26:04.000+0100
# ...                             ...
# 15976  2012-02-02T04:00:00.000+0100
# 15977  2012-02-02T03:56:00.000+0100
# 15978  2012-02-02T03:53:00.000+0100
# 15979  2012-02-01T04:13:00.000+0100
# 15980  2011-05-26T10:40:00.000+0200
#
#                                             Release Note Priority  \
# 0                                                    NaN  Blocker
# 1                                                    NaN    Minor
# 2                                                    NaN  Blocker
# 3                                                    NaN  Blocker
# 4                                                    NaN  Blocker
# ...                                                  ...      ...
# 15976  When importing data, the multisource module ha...      NaN
# 15977  Some bugs have been fixed and various improvem...      NaN
# 15978                                                NaN      NaN
# 15979                                                NaN      NaN
# 15980                                                NaN      NaN
#
#                             Created  ...      Components  \
# 0      2025-01-22T13:49:58.000+0100  ...       Oth/other
# 1      2025-01-21T11:59:10.000+0100  ...             NaN
# 2      2025-01-20T17:23:57.000+0100  ...             NaN
# 3      2025-01-20T16:06:24.000+0100  ...             NaN
# 4      2025-01-17T08:22:51.000+0100  ...             NaN
# ...                             ...  ...             ...
# 15976  2012-02-02T04:00:00.000+0100  ...        C/import
# 15977  2012-02-02T03:56:00.000+0100  ...  Cor/rule dict.
# 15978  2012-02-02T03:53:00.000+0100  ...  Gui/components
# 15979  2012-02-01T04:13:00.000+0100  ...       Oth/other
# 15980  2011-05-26T10:40:00.000+0200  ...      Gui/detail
#
#                  Fix Versions Parent Issue Watchers  \
# 0                         NaN          NaN        1
# 1                         NaN          NaN        0
# 2                         NaN          NaN        0
# 3      DH-7.1.0.0, DH-7.2.0.0          NaN        0
# 4      DH-7.1.0.0, DH-7.2.0.0          NaN        0
# ...                       ...          ...      ...
# 15976   DH-3.2-00b, DH-3.3-00          NaN        0
# 15977               DH-3.3-00          NaN        0
# 15978               DH-3.3-00          NaN        0
# 15979                     NaN          NaN        0
# 15980                     NaN          NaN        0
#
#                                              Issue Links Subtasks  \
# 0                                                    NaN      NaN
# 1      outward: depends on DHRD-100447 [Done] - Story...      NaN
# 2      inward: blocks DHRD-100501 [Blocked] - [DH-7.1...      NaN
# 3      inward: is created by DHRD-98328 [New] - [Clou...      NaN
# 4      outward: includes DHRD-103220 [To be tested] -...      NaN
# ...                                                  ...      ...
# 15976  outward: includes DHRD-21348 [Test failed] - [...      NaN
# 15977  outward: includes DHRD-21347 [Validated] - [DH...      NaN
# 15978  outward: includes DHRD-21346 [Validated] - [DH...      NaN
# 15979                                                NaN      NaN
# 15980                                                NaN      NaN
#
#                                                 Comments  \
# 0      [2025-01-22T13:58:13.000+0100] Hamid Ameziani:...
# 1      [2025-01-21T12:08:22.000+0100] Loic Brossard: ...
# 2      [2025-01-20T18:49:05.000+0100] Abir Arrari: Tr...
# 3      [2025-01-20T16:23:44.000+0100] Mukesh Mishra: ...
# 4      [2025-01-20T16:01:08.000+0100] Chaid Fatoumbi:...
# ...                                                  ...
# 15976                                                NaN
# 15977                                                NaN
# 15978                                                NaN
# 15979                                                NaN
# 15980                                                NaN
#
#                                           Module-Feature  \
# 0      {'self': 'https://nx-jira8.my-nx.com/rest/api/...
# 1      {'self': 'https://nx-jira8.my-nx.com/rest/api/...
# 2      {'self': 'https://nx-jira8.my-nx.com/rest/api/...
# 3      {'self': 'https://nx-jira8.my-nx.com/rest/api/...
# 4      {'self': 'https://nx-jira8.my-nx.com/rest/api/...
# ...                                                  ...
# 15976  {'self': 'https://nx-jira8.my-nx.com/rest/api/...
# 15977  {'self': 'https://nx-jira8.my-nx.com/rest/api/...
# 15978  {'self': 'https://nx-jira8.my-nx.com/rest/api/...
# 15979  {'self': 'https://nx-jira8.my-nx.com/rest/api/...
# 15980                                                NaN
#
#                                Module                        Feature
# 0      00 - Installation & Tech Admin  Installation - Run Components
# 1                     05 - Web Client     Web Navigation & Searching
# 2                   02 - System Admin  Scheduler, Tasks & Monitoring
# 3                 16 - Cloud & DevOps                 AWS Deployment
# 4                          15 - Tools                      Evaluator
# ...                               ...                            ...
# 15976     06 - Mapping & Connectivity                            NaN
# 15977                 01 - Core Admin                            NaN
# 15978                04 - Rich Client                            NaN
# 15979            09 - Data Enrichment                            NaN
# 15980                             NaN                            NaN
#
# [15981 rows x 25 columns]

# %%
# Nettoyer les textes
df['Description_Clean'] = df['Description'].apply(clean_text)
df['Summary_Clean'] = df['Summary'].apply(clean_text)

# %%
# Détecter la langue dans le Summary
df['Detected_Language_Summary'] = df['Summary_Clean'].apply(detect_language_lingua)

# %%
# Filtrer les lignes où la langue détectée dans le Summary est 'fr' (français)
french_summary_df = df[df['Detected_Language_Summary'] == 'fr']

# %%
# Extraire les 10 premières lignes du Summary des tickets en français
french_summary_texts = french_summary_df['Summary'].head(10).tolist()

# %%
# Appliquer la traduction
translated_texts = translate_corpus(french_summary_texts)
# Out:
# 100%|██████████| 10/10 [00:00<?, ?it/s]

# %%
translated_texts
# Out:
# ['CACEIS-PROD-IN-CP - Licence expirée depuis le 22/12/2024',
#  "Problème d'accès au client lourd DH à partir des environnement APAC aws",
#  '[TBV] Import Excel simulation',
#  '[TBF] Import csv simulation',
#  'Json file Import',
#  '[TBF] Json file Export',
#  'DEKABANK-SIT-RQ-DH- Impossible de lancer visage pour faire une démo - urgent',
#  'SGSS-SIT-PB-  [Migration V6] Problème de perf sur les import',
#  'AMUNDI-PROD-PB KYC - Problème de rafraichissement après sauvegarde de dossier',
#  "LBP-PROD-RQ- Demande d'archives sans  le binaire Log4J"]
